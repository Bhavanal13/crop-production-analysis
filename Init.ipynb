# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: biokit==0.5.0 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: statsmodels==0.14.5 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (0.14.5)
# Requirement already satisfied: bioservices>=1.4.5 in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: biopython in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (1.85)
# Requirement already satisfied: numpydoc in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: scipy in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: colormap in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (3.9.4)
# Requirement already satisfied: easydev>=0.9.34 in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (0.13.3)
# Requirement already satisfied: pandas in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: colorlog in /root/venv/lib/python3.9/site-packages (from biokit==0.5.0->-r ./requirements.txt (line 1)) (6.9.0)
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.14.5->-r ./requirements.txt (line 2)) (25.0)
# Requirement already satisfied: patsy>=0.5.6 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.14.5->-r ./requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.14.5->-r ./requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.13.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: suds-community<2.0.0,>=1.2.0 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: xmltodict<0.15.0,>=0.14.2 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.14.2)
# Requirement already satisfied: lxml<6.0.0,>=5.3.0 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (5.4.0)
# Requirement already satisfied: requests-cache<2.0.0,>=1.2.1 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: rich-click<2.0.0,>=1.8.5 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.8.9)
# Requirement already satisfied: grequests<0.8.0,>=0.7.0 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: wrapt<2.0.0,>=1.17.2 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /root/venv/lib/python3.9/site-packages (from bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /root/venv/lib/python3.9/site-packages (from easydev>=0.9.34->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: pexpect<5.0.0,>=4.9.0 in /root/venv/lib/python3.9/site-packages (from easydev>=0.9.34->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.2.0 in /root/venv/lib/python3.9/site-packages (from easydev>=0.9.34->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.3.8)
# Requirement already satisfied: line-profiler<5.0.0,>=4.1.2 in /root/venv/lib/python3.9/site-packages (from easydev>=0.9.34->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.59.0)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas->biokit==0.5.0->-r ./requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /root/venv/lib/python3.9/site-packages (from pandas->biokit==0.5.0->-r ./requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: sphinx>=6 in /root/venv/lib/python3.9/site-packages (from numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (7.4.7)
# Requirement already satisfied: tomli>=1.1.0 in /root/venv/lib/python3.9/site-packages (from numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: soupsieve>1.2 in /root/venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /root/venv/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: gevent in /root/venv/lib/python3.9/site-packages (from grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (25.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /root/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.9/site-packages (from pexpect<5.0.0,>=4.9.0->easydev>=0.9.34->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (2025.7.14)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.3->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.26.20)
# Requirement already satisfied: attrs>=21.2 in /root/venv/lib/python3.9/site-packages (from requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /root/venv/lib/python3.9/site-packages (from requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (25.1.1)
# Requirement already satisfied: url-normalize>=1.4 in /root/venv/lib/python3.9/site-packages (from requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: rich>=10.7 in /root/venv/lib/python3.9/site-packages (from rich-click<2.0.0,>=1.8.5->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (14.1.0)
# Requirement already satisfied: alabaster~=0.7.14 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: sphinxcontrib-jsmath in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: docutils<0.22,>=0.20 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.21.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: babel>=2.13 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: importlib-metadata>=6.0 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /root/venv/lib/python3.9/site-packages (from sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /root/venv/lib/python3.9/site-packages (from cattrs>=22.2->requests-cache<2.0.0,>=1.2.1->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.9/site-packages (from Jinja2>=3.1->sphinx>=6->numpydoc->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /root/venv/lib/python3.9/site-packages (from rich>=10.7->rich-click<2.0.0,>=1.8.5->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: zope.interface in /root/venv/lib/python3.9/site-packages (from gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (7.2)
# Requirement already satisfied: greenlet>=3.2.2 in /root/venv/lib/python3.9/site-packages (from gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (3.2.4)
# Requirement already satisfied: zope.event in /root/venv/lib/python3.9/site-packages (from gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: mdurl~=0.1 in /root/venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click<2.0.0,>=1.8.5->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: setuptools>=75.8.2 in /root/venv/lib/python3.9/site-packages (from zope.event->gevent->grequests<0.8.0,>=0.7.0->bioservices>=1.4.5->biokit==0.5.0->-r ./requirements.txt (line 1)) (80.9.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
'''!gdown --id 16iqC4KpA6WDC6jtr2bGJw6PTXTW_7Lv4 --output FAOSTAT_fertilizer_use_EU.csv
# !gdown --id 1S-I3wyRA1BvdxJfw71_tE92Y0mj2iOSC --output FAOSTAT_Wheat_production_EU.csv
# !gdown --id 15-MFq2DZjhUr1QOEyCCQyMdPx64Vtwca --output FAOSTAT_Temperature_EU.csv
# !gdown --id 1JSlaxg2wl8S2OPN_JYDcwlTJsJ_tpm0Q --output drought_EU.csv.csv
# !gdown --id 1-QtOwNotj7JW6qjPYHT94ut2X3BNidoD --output FAOSTAT_Pesticides_use_EU.csv.csv
'''
# Out:
# '!gdown --id 16iqC4KpA6WDC6jtr2bGJw6PTXTW_7Lv4 --output FAOSTAT_fertilizer_use_EU.csv\n!gdown --id 1S-I3wyRA1BvdxJfw71_tE92Y0mj2iOSC --output FAOSTAT_Wheat_production_EU.csv\n!gdown --id 15-MFq2DZjhUr1QOEyCCQyMdPx64Vtwca --output FAOSTAT_Temperature_EU.csv\n!gdown --id 1JSlaxg2wl8S2OPN_JYDcwlTJsJ_tpm0Q --output drought_EU.csv.csv\n!gdown --id 1-QtOwNotj7JW6qjPYHT94ut2X3BNidoD --output FAOSTAT_Pesticides_use_EU.csv.csv\n'
